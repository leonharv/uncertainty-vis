# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.neighbors import KernelDensity
import ipywidgets as widgets

# %%
x1 = np.random.uniform(4,6, 1000)
x2 = np.random.uniform(1,2, 1000)

T_s = 50
alpha = np.linspace(0, 1, T_s)
x = np.array([a * x2 + (1-a) * x1 for a in alpha])

print(x.shape)

plt.figure(figsize=(18,6))
plt.plot(alpha, x[:200,:], c='k', alpha=0.01)
plt.show()
# Out:
# (50, 1000)

# %%
T_v = 100
pdfs = np.empty((T_s, T_v))
for s in range(T_s):
    kde = KernelDensity(kernel='tophat', bandwidth=0.1).fit(x[s,:].reshape((-1,1)))
    x_plot = np.linspace(-1, 8, T_v)
    pdfs[s,:] = np.exp(kde.score_samples(x_plot.reshape((-1,1))))

# %%
s = 20
plt.figure(figsize=(18,6))
plt.subplot(2,1,1)
plt.title('ensembles')
plt.plot(x[:200,:], c='r', alpha=0.01)
#plt.imshow(pdfs.T, cmap='Reds', aspect='auto', origin='lower')
#plt.colorbar()
plt.grid()
plt.vlines(s, 0, 6, colors='tab:blue', ls='dashed')
plt.xticks(np.linspace(0,T_s,5), np.linspace(0,1,5))
#plt.yticks(np.linspace(0,T_v,5), np.linspace(-1,8,5))
#plt.ylim(0,T_v)
plt.xlabel('s')
plt.ylabel('v')

plt.subplot(2,1,2)
plt.title('KDE at v={:.2f}'.format(s/T_s))
plt.plot(pdfs[s,:])
plt.xticks(np.linspace(0,T_v,5), np.linspace(0,6,5))
plt.xlabel('v')

plt.tight_layout()
plt.show()

# %%
@widgets.interact(s=(0,T_s-1,1))
def show_pdf(s=0):
    plt.figure(figsize=(18,6))
    plt.subplot(2,1,1)
    plt.imshow(pdfs.T, cmap='Reds', aspect='auto', origin='lower')
    plt.colorbar()
    plt.vlines(s, 0, T_v, colors='k', ls='dashed')
    plt.xticks(np.linspace(0,T_s,5), np.linspace(0,1,5))
    plt.yticks(np.linspace(0,T_v,5), np.linspace(-1,8,5))
    plt.ylim(0,T_v)

    plt.subplot(2,1,2)
    plt.plot(pdfs[s,:])
    plt.ylim(0,2)

    plt.show()
# Out:
# interactive(children=(IntSlider(value=0, description='s', max=49), Output()), _dom_classes=('widget-interact',…

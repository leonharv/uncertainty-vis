# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
num_angle = 179
num_offset = 1
num_spotx = 180
chord_length = True
RSP_shape = [190, 1226]
filter_name='ramp'
chords = 'exact' if chord_length else 'map'

# %%
reconstruction = np.load('../../Data/simple_pCT/Reconstruction/Head/{:d}_{:d}/RSP_angles{:d}_offset{:d}_spotx{:d}_{:s}_{:s}.npy'.format(RSP_shape[0], RSP_shape[1], num_angle, num_offset, num_spotx, chords, filter_name))

# %%
plt.figure(figsize=(18,10))
plt.imshow(reconstruction, aspect='auto')
plt.colorbar()
plt.show()
